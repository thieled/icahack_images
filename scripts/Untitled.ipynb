# %%
# !pip install fer
# Out:
# Collecting fer
#   Downloading fer-22.5.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.9 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: requests in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from fer) (2.28.1)
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: keras>=2.0.0 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from fer) (2.13.1rc0)
# Requirement already satisfied: tqdm in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from fer) (4.65.0)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.7.0.72-cp37-abi3-macosx_11_0_arm64.whl (41.0 MB)
# Requirement already satisfied: matplotlib in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from fer) (3.7.1)
# Requirement already satisfied: pandas in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from fer) (2.0.0)
# Requirement already satisfied: numpy in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from facenet-pytorch->fer) (1.23.5)
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from facenet-pytorch->fer) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from matplotlib->fer) (1.0.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from pandas->fer) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from pandas->fer) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from requests->fer) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from requests->fer) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from requests->fer) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from requests->fer) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fer) (1.16.0)
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp310-none-macosx_11_0_arm64.whl (55.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 3.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from torch==2.0.1->torchvision->facenet-pytorch->fer) (3.1.2)
# Requirement already satisfied: networkx in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from torch==2.0.1->torchvision->facenet-pytorch->fer) (3.1)
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 4.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from torch==2.0.1->torchvision->facenet-pytorch->fer) (4.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sunyibing/miniconda3/lib/python3.10/site-packages (from jinja2->torch==2.0.1->torchvision->facenet-pytorch->fer) (2.1.1)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.0 MB/s eta 0:00:0000:01
# Installing collected packages: mpmath, sympy, opencv-contrib-python, filelock, torch, torchvision, facenet-pytorch, fer
# Successfully installed facenet-pytorch-2.5.3 fer-22.5.0 filelock-3.12.0 mpmath-1.3.0 opencv-contrib-python-4.7.0.72 sympy-1.12 torch-2.0.1 torchvision-0.15.2

# %%
from fer import FER
import matplotlib.pyplot as plt

# %%
import os
os.environ["IMAGEIO_FFMPEG_EXE"] = "/path/to/ffmpeg"

# %%
test_image_one = plt.imread("/Users/sunyibing/Downloads/B_nTSg5jpwn_2.jpg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)
# Out:
# [{'box': [650, 707, 156, 196], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 1.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}, {'box': [641, 28, 138, 179], 'emotions': {'angry': 0.01, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.92, 'sad': 0.03, 'surprise': 0.0, 'neutral': 0.03}}]
